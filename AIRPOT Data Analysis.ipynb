# %% [markdown]
# # We're Analysing Cab Drives in New york city

# %% [markdown]
# # Questions we'll like to attend to
# 1. Mean speed of all the rides
# 2. Number of rides taken in February
# 3. Number of rides where tip more than $50
# 4. Number of rides where drop was JFK airport

# %%
import numpy as np
import pandas as pd

# %%
file_path="C:/Users/LICT/Downloads/nyc_taxis.csv"
df = pd.read_csv(file_path)

print(df.head())
# Out:
#    pickup_year  pickup_month  pickup_day  pickup_dayofweek  pickup_time  \
# 0         2016             1           1                 5            0
# 1         2016             1           1                 5            0
# 2         2016             1           1                 5            0
# 3         2016             1           1                 5            0
# 4         2016             1           1                 5            0
#
#    pickup_location_code  dropoff_location_code  trip_distance  trip_length  \
# 0                     2                      4          21.00         2037
# 1                     2                      1          16.29         1520
# 2                     2                      6          12.70         1462
# 3                     2                      6           8.70         1210
# 4                     2                      6           5.56          759
#
#    fare_amount  fees_amount  tolls_amount  tip_amount  total_amount  \
# ...

# %%
taxi=file_path

# %%
df
# Out:
#        pickup_year  pickup_month  pickup_day  pickup_dayofweek  pickup_time  \
# 0             2016             1           1                 5            0
# 1             2016             1           1                 5            0
# 2             2016             1           1                 5            0
# 3             2016             1           1                 5            0
# 4             2016             1           1                 5            0
# ...            ...           ...         ...               ...          ...
# 89555         2016             6          30                 4            5
# 89556         2016             6          30                 4            5
# 89557         2016             6          30                 4            5
# 89558         2016             6          30                 4            5
# 89559         2016             6          30                 4            5
#
# ...

# %%
taxi = np.genfromtxt('nyc_taxis.csv', delimiter = ',',skip_header = True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 taxi = np.genfromtxt('nyc_taxis.csv', delimiter = ',',skip_header = True)
#
# File ~\anaconda3\Lib\site-packages\numpy\lib\npyio.py:1977, in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding, ndmin, like)
#    1975     fname = os_fspath(fname)
#    1976 if isinstance(fname, str):
# -> 1977     fid = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1978     fid_ctx = contextlib.closing(fid)
#    1979 else:
#
# File ~\anaconda3\Lib\site-packages\numpy\lib\_datasource.py:193, in open(path, mode, destpath, encoding, newline)
#     156 """
# ...

# %%
#Now to calculate the speed of cars in miles/hrs...
speed = int(file_path[:,7]/ taxi[:,8]/3600)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 #Now to calculate the speed of cars in miles/hrs...
# ----> 2 speed = int(file_path[:,7]/ taxi[:,8]/3600)
#
# TypeError: string indices must be integers, not 'tuple'

# %%
taxi.df()
